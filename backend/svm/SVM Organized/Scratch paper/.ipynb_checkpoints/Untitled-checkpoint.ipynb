# %%
import pymongo
from pymongo import MongoClient
import time

# %%
client = MongoClient("mongodb://compute1.cognac.cs.fiu.edu:59122/PatentData?readPreference=secondary&ssl=false")

# %%
db = client['PatentData']

# %%
cluster = db['labels']

# %%
with db.watch() as stream:
    while stream.alive:
        print('blocking')
        change = stream.next()
        print('not blocking')
        if change is not None:
            print(change)
            continue_after = change['_id']
            break
# Out:
# blocking
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-b403e53e619e> in <module>
#       2     while stream.alive:
#       3         print('blocking')
# ----> 4         change = stream.next()
#       5         print('not blocking')
#       6         if change is not None:
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/change_stream.py in next(self)
#     247         """
#     248         while self.alive:
# --> 249             doc = self.try_next()
#     250             if doc is not None:
#     251                 return doc
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/change_stream.py in try_next(self)
#     301         # one resume attempt.
#     302         try:
# --> 303             change = self._cursor._try_next(True)
#     304         except (ConnectionFailure, CursorNotFound):
#     305             self._resume()
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     268         """Advance the cursor blocking for at most one getMore command."""
#     269         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 270             self._refresh()
#     271         if len(self.__data):
#     272             coll = self.__collection
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/command_cursor.py in _refresh(self)
#     194             dbname, collname = self.__ns.split('.', 1)
#     195             read_pref = self.__collection._read_preference_for(self.session)
# --> 196             self.__send_message(
#     197                 self._getmore_class(dbname,
#     198                                     collname,
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     137         client = self.__collection.database.client
#     138         try:
# --> 139             response = client._run_operation_with_response(
#     140                 operation, self._unpack_response, address=self.__address)
#     141         except OperationFailure:
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/mongo_client.py in _run_operation_with_response(self, operation, unpack_res, exhaust, address)
#    1366                 unpack_res)
#    1367
# -> 1368         return self._retryable_read(
#    1369             _cmd, operation.read_preference, operation.session,
#    1370             address=address,
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
#    1469                         # not support retryable reads, raise the last error.
#    1470                         raise last_error
# -> 1471                     return func(session, server, sock_info, slave_ok)
#    1472             except ServerSelectionTimeoutError:
#    1473                 if retrying:
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, slave_ok)
#    1358
#    1359         def _cmd(session, server, sock_info, slave_ok):
# -> 1360             return server.run_operation_with_response(
#    1361                 sock_info,
#    1362                 operation,
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/server.py in run_operation_with_response(self, sock_info, operation, set_slave_okay, listeners, exhaust, unpack_res)
#     115             if send_message:
#     116                 sock_info.send_message(data, max_doc_size)
# --> 117                 reply = sock_info.receive_message(request_id)
#     118             else:
#     119                 reply = sock_info.receive_message(None)
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     724             return receive_message(self, request_id, self.max_message_size)
#     725         except BaseException as error:
# --> 726             self._raise_connection_failure(error)
#     727
#     728     def _raise_if_not_writable(self, unacknowledged):
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     722         """
#     723         try:
# --> 724             return receive_message(self, request_id, self.max_message_size)
#     725         except BaseException as error:
#     726             self._raise_connection_failure(error)
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     193     # Ignore the response's request id.
#     194     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 195         _receive_data_on_socket(sock_info, 16, deadline))
#     196     # No request_id for exhaust cursor "getMore".
#     197     if request_id is not None:
#
# ~/capstone/al_env/lib/python3.9/site-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     284             try:
#     285                 wait_for_read(sock_info, deadline)
# --> 286                 chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     287             except (IOError, OSError) as exc:
#     288                 if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %%
print(continue_after)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6f2e40897b02> in <module>
# ----> 1 print(continue_after)
#
# NameError: name 'continue_after' is not defined
